# %%
import pandas as pd
garmin_excercise = pd.read_csv('excercise_myfit.csv')
garmin_excercise.head()
# Out:
#          Date                           Exercise      Type  Exercise Calories  \
# 0  2013-05-22                        Biceps Curl  Strength                NaN
# 1  2019-04-27  Garmin Connect calorie adjustment    Cardio             1115.0
# 2  2019-04-28  Garmin Connect calorie adjustment    Cardio              233.0
# 3  2019-04-29  Garmin Connect calorie adjustment    Cardio              132.0
# 4  2019-04-30  Garmin Connect calorie adjustment    Cardio              229.0
#
#    Exercise Minutes  Sets  Reps Per Set  Pounds  Steps  Note
# 0               NaN   3.0          20.0    20.0    NaN   NaN
# 1               1.0   NaN           NaN     NaN    NaN   NaN
# 2               1.0   NaN           NaN     NaN    NaN   NaN
# 3               1.0   NaN           NaN     NaN    NaN   NaN
# 4               1.0   NaN           NaN     NaN    NaN   NaN

# %%
garmin_activities = pd.read_csv('garmin_activities.csv')
garmin_activities.head()
# Out:
#        Activity Type                 Date  Favorite                     Title  \
# 0            Running  2021-07-20 12:27:43     False          Portland Running
# 1            Walking  2021-07-17 13:16:37     False  Clackamas County Walking
# 2            Running  2021-07-16 11:53:06     False          Portland Running
# 3  Strength Training  2021-07-13 16:49:06     False                  Strength
# 4            Running  2021-07-07 12:13:49     False          Portland Running
#
#   Distance Calories      Time Avg HR Max HR Aerobic TE  ... Min Temp  \
# 0     2.04      252  00:21:30    156    181        3.2  ...     73.4
# 1     7.27      928  02:51:07    110    146        1.5  ...     78.8
# 2     3.00      378  00:31:24    161    183        3.8  ...     73.4
# 3     0.00       39  00:15:30     81    106        0.1  ...     78.8
# 4     3.07      368  00:34:14    149    176        3.2  ...     71.6
#
#   Surface Interval Decompression Best Lap Time Number of Laps Max Temp  \
# ...

# %%
#garmin_activities.describe()
for number in garmin_activities['Distance']:
  if ',' in number:
    print(number,i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4128/3246918233.py in <module>
#       1 #garmin_activities.describe()
# ----> 2 for number, i in garmin_activities['Distance']:
#       3   if ',' in number:
#       4     print(number,i)
#
# ValueError: too many values to unpack (expected 2)

# %%
for col in garmin_activities.columns:
  #try:
   
    
  if (garmin_activities[col].max() == 0.0 and garmin_activities[col].min()<=0.0):
    print(garmin_activities.drop(col, inplace=True,axis=1))
    
  #except:
  print(col)
# Out:
# Activity Type
# Date
# Title
# Distance
# Calories
# Time
# Avg HR
# Max HR
# Aerobic TE
# Avg Run Cadence
# Max Run Cadence
# Avg Pace
# Best Pace
# Elev Gain
# Elev Loss
# Avg Stride Length
# None
# Avg Vertical Ratio
# None
# Avg Vertical Oscillation
# None
# Training Stress Score®
# None
# Grit
# None
# Flow
# Total Strokes
# Avg. Swolf
# Avg Stroke Rate
# Total Reps
# Total Sets
# Climb Time
# Bottom Time
# Min Temp
# Surface Interval
# Decompression
# Best Lap Time
# Number of Laps
# None
# Max Temp
# Moving Time
# Elapsed Time
# Min Elevation
# Max Elevation

# %%
garmin_activities.columns
# Out:
# Index(['Activity Type', 'Date', 'Title', 'Distance', 'Calories', 'Time',
#        'Avg HR', 'Max HR', 'Aerobic TE', 'Avg Run Cadence', 'Max Run Cadence',
#        'Avg Pace', 'Best Pace', 'Elev Gain', 'Elev Loss', 'Avg Stride Length',
#        'Total Strokes', 'Avg. Swolf', 'Avg Stroke Rate', 'Total Reps',
#        'Total Sets', 'Climb Time', 'Bottom Time', 'Min Temp',
#        'Surface Interval', 'Decompression', 'Best Lap Time', 'Number of Laps',
#        'Moving Time', 'Elapsed Time', 'Min Elevation', 'Max Elevation'],
#       dtype='object')

# %%
garmin_activities['Distance'].astype('float').dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4128/398583757.py in <module>
# ----> 1 garmin_activities['Distance'].astype('float').dtypes
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# ...

# %%
garmin_activities['Distance'].describe()
# Out:
# count      277
# unique     138
# top       0.00
# freq        79
# Name: Distance, dtype: object
